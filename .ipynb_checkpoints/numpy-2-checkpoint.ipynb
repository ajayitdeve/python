# %%
#reshape and trnspose
import numpy as np
a1=np.array([[1,2],[3,4],[4,5]])
a1.shape
# Out:
# (3, 2)

# %%
a2=np.array([[1,2,3],[4,5,6]])
a2.shape
a3=a2.reshape(2,3).shape
a1
a3
a1*a3
# Out:
# array([[ 2,  6],
#        [ 6, 12],
#        [ 8, 15]])

# %%
#transpose : switches the axis
a1.shape
# Out:
# (3, 2)

# %%
a1.T.shape
# Out:
# (2, 3)

# %%
#76 Comparision Operator
