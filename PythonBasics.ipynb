# %%
#32-Type Conversion
print(type(str(200)))
# Out:
# <class 'str'>

# %%
#33 Escape Sequence
wether="\t Hey it\'s very hot \n today"
print(wether)
# Out:
# 	 Hey it's very hot
#  today

# %%
#34 Formatted String 
name="Ajay"
age=45
print("Hi "+name+" You are "+str(age)+" year old")

## same with formatted string
print(f'Hi {name} you are {age} year old')

# format is used mostly in Python 3
print("Hi {} you are {} year Old".format("Rakesh",30))

#or 
print("Hi {} you are {} year old".format('Swadha',17))

#Or
print("Hi {1} you are {0} years old".format(age,name))

#or
print("Hi {new_name} you are {new_age} years old".format(new_name="Bhavya",new_age=5))
# Out:
# Hi Ajay You are 45 year old
# Hi Ajay you are 45 year old
# Hi Rakesh you are 30 year Old
# Hi Swadha you are 17 year old
# Hi Ajay you are 45 years old
# Hi Bhavya you are 5 years old

# %%
#36 String Indexes
selfish='01234567'
#[start:stop]
print(selfish[0:2])
print(selfish[0:8])

#[start:stop:steopover]
print(selfish[0:8:1])

#reverse the string
print(selfish[::-1])

print(selfish[1:])
# Out:
# 01
# 01234567
# 01234567
# 76543210
# 1234567

# %%
#36 Immutability 
# strings are in Python is immutibale means can not be changed
selfish='01234567'
#selfish[0]='8'
#we can not assign part of string
#throw error:TypeError: 'str' object does not support item assignment
#the only way to change the string is complete reassignement
selfish='81234567'

# %%
#37 Builtin functions and method
print(len('hello'))
greet="Good Morning"
print(greet[0:len(greet)])

quote='to be or not to be'
print(quote.upper())
print(quote.capitalize())

#find  first  occurance of be
print(quote.find('be'))


print(quote.replace('be','me'))
print(quote)

quote2=quote.replace('be','me')
print(quote2)
# Out:
# 5
# Good Morning
# TO BE OR NOT TO BE
# To be or not to be
# 3
# to me or not to me
# to be or not to be
# to me or not to me

# %%
#38 Booleals #booleans : bool can be only true or false

name="Ajay"
is_cool=False
is_cool=True

print(bool(1))
#converting string into Boolean
print(bool('True'))
# Out:
# True
# True

# %%
#39exercise : Type Conversion

#user input
birth_year=input('What year you born?')
age=2025-int(birth_year)
print(f"Your age is :{age}")
# Out:
# What year you born? 1980
# Your age is :45

# %%
#41 Password checker
user_name=input("Enter your user name ::");
password=input("Enter your password")
password_length=len(password)
print(f"Your password is {'*'*password_length} {password_length} long")
# Out:
# Enter your user name :: dasfdsf
# Enter your password dsfdsf
# Your password is ****** 6 long

# %%
#42 Lists 
#List is the ordered sequence of objects that can be nay type
li1=[1,2,3,4,5,6,7,8]
li2=['a','b',1,2,5.9,True,False];

amazon_cart=['Notebook','Sunglasses','Toys','Graps'] 

# List slicing also available same as string slicing
print(amazon_cart[0:2])
#zero to end with stepover 2
print(amazon_cart[0::2])

#list are not immutable , means we can change the iteams of the list
amazon_cart[0]='Laptop';
print(amazon_cart)
# Out:
# ['Notebook', 'Sunglasses']
# ['Notebook', 'Toys']
# ['Laptop', 'Sunglasses', 'Toys', 'Graps']

# %%
#43 List Slicing
''' 
In Python, when you assign one list to another using the assignment operator (=), it is not a copy by value but rather a copy of the reference to the list object. This means both variables now point to the exact same list object in memory.
Consider the following example:
list1 = [1, 2, 3]
list2 = list1  # list2 now references the same list object as list1
list2.append(4)
print(list1)
print(list2)
----------------Out Put---
[1, 2, 3, 4]
[1, 2, 3, 4]
'''
amazon_cart=['Notebook','Sunglas','Toys','Grapes']
amazon_cart[0]='Laptop'
print(amazon_cart[0:3])  # when we slice a list , it dot affet the original list , it is the totally new list, if we need we can assign it to another variable
print(amazon_cart)


new_list=amazon_cart[0:3]
print(f"\n new list {new_list}")

# but if insted of slicing a list assign list to anoter 
#new_list=amazon_cart   # here assignment is by ref that why both valibale new_list and amazon_cat are pointing the sma memory location
#to copy one list to another 
new_list=amazon_cart[:]
amazon_cart[1]='changed Item'
print(f"\n new list {new_list}")
print(f"\n amazon list {amazon_cart}")
# Out:
# ['Laptop', 'Sunglas', 'Toys']
# ['Laptop', 'Sunglas', 'Toys', 'Grapes']
#
#  new list ['Laptop', 'Sunglas', 'Toys']
#
#  new list ['Laptop', 'Sunglas', 'Toys', 'Grapes']
#
#  amazon list ['Laptop', 'changed Item', 'Toys', 'Grapes']
