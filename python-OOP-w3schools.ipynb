# %%
class Person:
    def __init__(self,name,email,mobile):
        self.name=name
        self.email=email
        self.mobile=mobile

p1=Person("Ajay","Ajayitguru@gmail.com","8130271181")
print(f"Name={p1.name} Email= {p1.email} Mobile ={p1.mobile}")
# Out:
# Name=Ajay Email= Ajayitguru@gmail.com Mobile =8130271181

# %%
class Person1:
  pass

p1 = Person1()
p1.name = "Tobias"
p1.age = 25

print(p1.name)
print(p1.age)
# Out:
# Tobias
# 25

# %%
class Per:
    def __init__(self,name,email):
        self.name=name
        self.email=email
    def greet(self):
        print(f"Hi {self.name}, your email is {self.email}")

obj=Per("Ajay","ajaydomain@gmail.com")
obj.greet()
# Out:
# Hi Ajay, your email is ajaydomain@gmail.com

# %% [markdown]
# Class Properties

# %%
#create a class with properties
class Emp:
    def __init__(self,name,age):
        self.name=name
        self.age=age

e=Emp("Ajay",45)
print(f"{e.name}  {e.age}")
# Out:
# Ajay  45

# %%
#Modify Properties
e.age=46
print(e.age)

#delete Properties
del e.age
#print(e.age) this will throw error as age property deleted
# Out:
# 46

# %% [markdown]
# Class Properties vs Object Properties

# %%
#Properties defined inside __init__() belong to each object (instance properties).

#Properties defined outside methods belong to the class itself (class properties) and are shared by all objects:
class Pers:
  species = "Human" # Class property

  def __init__(self, name):
    self.name = name # Instance property

p1 = Pers("Emil")
p2 = Pers("Tobias")

print(p1.name)
print(p2.name)
print(p1.species)
print(p2.species)
# Out:
# Emil
# Tobias
# Human
# Human

# %%
#chnge a class Property
class Person:
  lastname = ""

  def __init__(self, name):
    self.name = name

p1 = Person("Linus")
p2 = Person("Emil")

Person.lastname = "Refsnes"

print(p1.lastname)
print(p2.lastname)
# Out:
# Refsnes
# Refsnes

# %%
#add New Property
class Person:
  def __init__(self, name):
    self.name = name

p1 = Person("Tobias")

p1.age = 25
p1.city = "Oslo"

print(p1.name)
print(p1.age)
print(p1.city)
# Out:
# Tobias
# 25
# Oslo
