# %%
#reshape and trnspose
import numpy as np
a1=np.array([[1,2],[3,4],[4,5]])
a1.shape
# Out:
# (3, 2)

# %%
a2=np.array([[1,2,3],[4,5,6]])
a2.shape
a3=a2.reshape(2,3).shape
a1
a3
a1*a3
# Out:
# array([[ 2,  6],
#        [ 6, 12],
#        [ 8, 15]])

# %%
#transpose : switches the axis
a1.shape
# Out:
# (3, 2)

# %%
a1.T.shape
# Out:
# (2, 3)

# %%
#74 Dot Product vs element wise
np.random.seed(0)
mat1=np.random.randint(10,size=(2,2))
mat2=np.random.randint(10,size=(2,2))

# %%
mat1.shape
# Out:
# (2, 2)

# %%
mat1
# Out:
# array([[5, 0],
#        [3, 3]], dtype=int32)

# %%
mat2.shape
# Out:
# (2, 2)

# %%
mat2
# Out:
# array([[7, 9],
#        [3, 5]], dtype=int32)

# %%
mat1 * mat2
# Out:
# array([[35,  0],
#        [ 9, 15]], dtype=int32)

# %%
#76 Comparision Operators
a1 == a1
# Out:
# array([[ True,  True],
#        [ True,  True],
#        [ True,  True]])

# %%
#77 Sorting Array

# %%
#78 Turn Images Into NumPy Arrays
#turn an image into numpy array
